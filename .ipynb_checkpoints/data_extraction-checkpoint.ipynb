# %%
# Import libraries
import requests
from bs4 import BeautifulSoup
base_url = "https://www.nhtsa.gov/file-downloads?p=nhtsa/downloads/FARS"


url = f"{base_url}/2019/National/"
# URL from which pdfs to be downloaded

response = requests.get(url)

# Parse text obtained
soup = BeautifulSoup(response.text, 'html.parser')

# %%
def get_download_link(year):
    base_url = "https://www.nhtsa.gov/file-downloads?p=nhtsa/downloads/FARS"
    print(year)

    url = f"{base_url}/{year}/National/"
    response = requests.get(url)
    li=[]
    soup = BeautifulSoup(response.text, 'html.parser')

    for l in soup.find_all('a'):
        if('NationalCSV.zip' in l.get('href')):
            #print(l.get('href'))
            li.append(l.get('href'))
    return li[1]

# %%
a=get_download_link(2018)
# Out:
# 2018

# %%
links=[]
for i in range(2015,2022):
    links.append(get_download_link(i))
# Out:
# 2015
# 2016
# 2017
# 2018
# 2019
# 2020
# 2021

# %%
links
# Out:
# ['https://static.nhtsa.gov/nhtsa/downloads/FARS/2015/National/FARS2015NationalCSV.zip',
#  'https://static.nhtsa.gov/nhtsa/downloads/FARS/2016/National/FARS2016NationalCSV.zip',
#  'https://static.nhtsa.gov/nhtsa/downloads/FARS/2017/National/FARS2017NationalCSV.zip',
#  'https://static.nhtsa.gov/nhtsa/downloads/FARS/2018/National/FARS2018NationalCSV.zip',
#  'https://static.nhtsa.gov/nhtsa/downloads/FARS/2019/National/FARS2019NationalCSV.zip',
#  'https://static.nhtsa.gov/nhtsa/downloads/FARS/2020/National/FARS2020NationalCSV.zip',
#  'https://static.nhtsa.gov/nhtsa/downloads/FARS/2021/National/FARS2021NationalCSV.zip']

# %%
y=2015
for i in links:
    r = requests.get(i, stream = True) 
    
    with open("traffic"+str(y)+".zip","wb") as zip: 
        y=y+1
        print(y)
        for chunk in r.iter_content(chunk_size=1024): 
  
         # writing one chunk at a time to pdf file 
             if chunk: 
                 zip.write(chunk)
# Out:
# 2016
# 2017
# 2018
# 2019
# 2020
# 2021
# 2022

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en" prefix="og: https://ogp.me/ns#">
#  <head>
#   <title>
#    NHTSA File Downloads | NHTSA
#   </title>
#   <link href="/sites/nhtsa.gov/files/css/css_7F4bPOgJ21U2sIm55wdstOxNMGqzAXZSnQotwUaP4f8.css?delta=0&amp;language=en&amp;theme=nhtsa&amp;include=eJzLyygpTtRPz8lPSszRLS6pzMnMS9cpriwuSc3VT0osTgUA0A4MkQ" media="all" rel="stylesheet"/>
#   <link href="https://fonts.googleapis.com/css?family=Roboto+Condensed:400,400i,700,700i|Roboto+Slab:300,400,700|Roboto:100,300,400,400i,500,700,900" media="all" rel="stylesheet"/>
#   <meta charset="utf-8"/>
#   <link href="https://www.nhtsa.gov/file-downloads" rel="canonical"/>
#   <link href="/themes/custom/nhtsa/images/NHTSA-media-share-logo.png" rel="image_src"/>
#   <meta content="NHTSA" property="og:site_name"/>
#   <meta content="https://www.nhtsa.gov/file-downloads" property="og:url"/>
#   <meta content="NHTSA File Downloads | NHTSA" property="og:title"/>
# ...

# %% [markdown]
# # Extract Accident files from zipped files

# %%
import os
import zipfile

# Path to the zipped file
zip_file_path = r"C:\Users\adnan\Downloads\FARS2021NationalCSV.zip"

# Name of the file to extract from the zip
f1=r'FARS2021NationalCSV'
file_csv = r'accident.csv'
file_to_extract=os.path.join(f1,file_csv)
print(file_to_extract)
file_to_extract=file_to_extract.replace(os.sep, '/')
print(file_to_extract)
# Directory to create for saving the extracted file
output_folder = r'extracted_files'

# Create the output folder if it doesn't exist
os.makedirs(output_folder, exist_ok=True)


with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    
    if file_to_extract in zip_ref.namelist():
        f_name=os.path.join(output_folder,f1)
        zip_ref.extract(file_to_extract, output_folder)
        os.rename(current_folder_path, new_folder_name)
        
        print(f"File '{file_to_extract}' extracted to '{output_folder}'")
        
    else:
        print(f"File '{file_to_extract}' not found in the zip file.")
# Out:
# FARS2021NationalCSV\accident.csv
# FARS2021NationalCSV/accident.csv
# File 'FARS2021NationalCSV/accident.csv' extracted to 'extracted_files'

# %%
files1=[]
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    # List all files in the zip archive
    print("Files in the zip archive:")
    for file in zip_ref.namelist():
        print(f" - {file}")
        files1.append(file)
    # Check if the file exists in the zip
    if file_to_extract in zip_ref.namelist():
        # Extract the specific file to the output folder
        zip_ref.extract(file_to_extract, output_folder)
        print(f"File '{file_to_extract}' extracted to '{output_folder}'")
    else:
        print(f"Error: File '{file_to_extract}' not found in the zip file.")
# Out:
# Files in the zip archive:
#  - FARS2021NationalCSV/accident.csv
#  - FARS2021NationalCSV/cevent.csv
#  - FARS2021NationalCSV/crashrf.csv
#  - FARS2021NationalCSV/damage.csv
#  - FARS2021NationalCSV/distract.csv
#  - FARS2021NationalCSV/drimpair.csv
#  - FARS2021NationalCSV/driverrf.csv
#  - FARS2021NationalCSV/drugs.csv
#  - FARS2021NationalCSV/factor.csv
#  - FARS2021NationalCSV/maneuver.csv
#  - FARS2021NationalCSV/MIACC.CSV
#  - FARS2021NationalCSV/MIDRVACC.CSV
#  - FARS2021NationalCSV/MIPER.CSV
#  - FARS2021NationalCSV/nmcrash.csv
#  - FARS2021NationalCSV/nmdistract.csv
#  - FARS2021NationalCSV/nmimpair.csv
#  - FARS2021NationalCSV/nmprior.csv
#  - FARS2021NationalCSV/parkwork.csv
#  - FARS2021NationalCSV/pbtype.csv
#  - FARS2021NationalCSV/person.csv
#  - FARS2021NationalCSV/personrf.csv
#  - FARS2021NationalCSV/pvehiclesf.csv
#  - FARS2021NationalCSV/race.csv
#  - FARS2021NationalCSV/safetyeq.csv
#  - FARS2021NationalCSV/vehicle.csv
#  - FARS2021NationalCSV/vehiclesf.csv
# ...

# %%
import os


directory = r"C:\Users\adnan\Desktop\python\extracted_files"  

# Specify the current folder name and the new folder name
current_name = "FARS2021NationalCSV"
new_name = "Traffic"

# Create full paths
current_path = os.path.join(directory, current_name)
new_path = os.path.join(directory, new_name)

# Rename the folder

os.rename(current_path, new_path)
