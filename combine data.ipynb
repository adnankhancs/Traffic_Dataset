# %%
import pandas as pd

# %%
x=[]
for i in range(2015,2022):
    print(i)
    url=r"C:\Users\adnan\Desktop\python\traffic"+str(i)+r"\accident.CSV"
    a=pd.read_csv(url,encoding = 'latin')
    x.append(a)
# Out:
# 2015
# 2016
# 2017
# C:\Users\adnan\AppData\Local\Temp\ipykernel_24320\148360440.py:5: DtypeWarning: Columns (40,42) have mixed types. Specify dtype option on import or set low_memory=False.
#   a=pd.read_csv(url,encoding = 'latin')
# 2018
# 2019
# C:\Users\adnan\AppData\Local\Temp\ipykernel_24320\148360440.py:5: DtypeWarning: Columns (40,42) have mixed types. Specify dtype option on import or set low_memory=False.
#   a=pd.read_csv(url,encoding = 'latin')
# 2020
# 2021

# %%
x
# Out:
# [       STATE STATENAME  ST_CASE  VE_TOTAL  VE_FORMS  PVH_INVL  PEDS  PERSONS  \
#  0          1   Alabama    10001         1         1         0     0        1
#  1          1   Alabama    10002         1         1         0     0        1
#  2          1   Alabama    10003         1         1         0     0        2
#  3          1   Alabama    10004         1         1         0     0        1
#  4          1   Alabama    10005         2         2         0     0        2
#  ...      ...       ...      ...       ...       ...       ...   ...      ...
#  32533     56   Wyoming   560126         2         2         0     0        2
#  32534     56   Wyoming   560127         1         1         0     0        3
#  32535     56   Wyoming   560128         2         2         0     0        2
#  32536     56   Wyoming   560129         2         2         0     0        4
#  32537     56   Wyoming   560130         1         1         0     0        1
#
# ...

# %%
for i in x:
    print(i.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32538 entries, 0 to 32537
# Data columns (total 89 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   STATE         32538 non-null  int64
#  1   STATENAME     32538 non-null  object
#  2   ST_CASE       32538 non-null  int64
#  3   VE_TOTAL      32538 non-null  int64
#  4   VE_FORMS      32538 non-null  int64
#  5   PVH_INVL      32538 non-null  int64
#  6   PEDS          32538 non-null  int64
#  7   PERSONS       32538 non-null  int64
#  8   PERMVIT       32538 non-null  int64
#  9   PERNOTMVIT    32538 non-null  int64
#  10  COUNTY        32538 non-null  int64
#  11  CITY          32538 non-null  int64
#  12  DAY           32538 non-null  int64
#  13  DAYNAME       32538 non-null  int64
#  14  MONTH         32538 non-null  int64
#  15  MONTHNAME     32538 non-null  object
#  16  YEAR          32538 non-null  int64
#  17  DAY_WEEK      32538 non-null  int64
# ...

# %%
for i in x:
    print(len(i.columns))
# Out:
# 89
# 91
# 91
# 91
# 91
# 81
# 80

# %%
for i in x[1].columns:
    if i not in x[6]:
        print(i)
# Out:
# WEATHER1
# WEATHER1NAME
# WEATHER2
# WEATHER2NAME
# CF1
# CF1NAME
# CF2
# CF2NAME
# CF3
# CF3NAME
# DRUNK_DR

# %%
for i in x[1].columns:
    if i not in x[6]:
        print(i)
# Out:
# WEATHER1
# WEATHER1NAME
# WEATHER2
# WEATHER2NAME
# CF1
# CF1NAME
# CF2
# CF2NAME
# CF3
# CF3NAME
# DRUNK_DR

# %%
x[1]["YEAR"]
# Out:
# 0        2016
# 1        2016
# 2        2016
# 3        2016
# 4        2016
#          ...
# 34743    2016
# 34744    2016
# 34745    2016
# 34746    2016
# 34747    2016
# Name: YEAR, Length: 34748, dtype: int64

# %%
final=pd.concat(x,join='inner', ignore_index=True)

# %%
final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244972 entries, 0 to 244971
# Data columns (total 78 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   STATE         244972 non-null  int64
#  1   STATENAME     244972 non-null  object
#  2   ST_CASE       244972 non-null  int64
#  3   VE_TOTAL      244972 non-null  int64
#  4   VE_FORMS      244972 non-null  int64
#  5   PVH_INVL      244972 non-null  int64
#  6   PEDS          244972 non-null  int64
#  7   PERSONS       244972 non-null  int64
#  8   PERMVIT       244972 non-null  int64
#  9   PERNOTMVIT    244972 non-null  int64
#  10  COUNTY        244972 non-null  int64
#  11  CITY          244972 non-null  int64
#  12  DAY           244972 non-null  int64
#  13  DAYNAME       244972 non-null  int64
#  14  MONTH         244972 non-null  int64
#  15  MONTHNAME     244972 non-null  object
#  16  YEAR          244972 non-null  int64
#  17  DAY_WEEK      244972 non-null  int64
# ...

# %%
final.describe()
# Out:
#                STATE        ST_CASE       VE_TOTAL       VE_FORMS  \
# count  244972.000000  244972.000000  244972.000000  244972.000000
# mean       27.140175  272191.999927       1.573837       1.533167
# std        16.385494  163742.659135       0.881140       0.839772
# min         1.000000   10001.000000       1.000000       1.000000
# 25%        12.000000  121922.000000       1.000000       1.000000
# 50%        26.000000  260876.000000       1.000000       1.000000
# 75%        42.000000  420475.000000       2.000000       2.000000
# max        56.000000  560130.000000     130.000000     130.000000
#
#             PVH_INVL           PEDS        PERSONS        PERMVIT  \
# count  244972.000000  244972.000000  244972.000000  244972.000000
# mean        0.040670       0.226842       2.242942       2.232369
# std         0.293969       0.476248       1.803382       1.799218
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
len(final.columns)
# Out:
# 78

# %%
uncommon=[]
for i in x:
    for c in i.columns:
        if c not in final.columns:
            uncommon.append(c)

# %%
uncommon
# Out:
# ['WEATHER1',
#  'WEATHER1NAME',
#  'WEATHER2',
#  'WEATHER2NAME',
#  'CF1',
#  'CF1NAME',
#  'CF2',
#  'CF2NAME',
#  'CF3',
#  'CF3NAME',
#  'DRUNK_DR',
#  'COUNTYNAME',
#  'CITYNAME',
#  'WEATHER1',
#  'WEATHER1NAME',
#  'WEATHER2',
#  'WEATHER2NAME',
#  'CF1',
#  'CF1NAME',
#  'CF2',
#  'CF2NAME',
#  'CF3',
#  'CF3NAME',
#  'DRUNK_DR',
#  'COUNTYNAME',
#  'CITYNAME',
#  'WEATHER1',
#  'WEATHER1NAME',
#  'WEATHER2',
#  'WEATHER2NAME',
#  'CF1',
#  'CF1NAME',
#  'CF2',
#  'CF2NAME',
#  'CF3',
#  'CF3NAME',
#  'DRUNK_DR',
#  'COUNTYNAME',
#  'CITYNAME',
#  'WEATHER1',
#  'WEATHER1NAME',
#  'WEATHER2',
#  'WEATHER2NAME',
#  'CF1',
#  'CF1NAME',
#  'CF2',
#  'CF2NAME',
#  'CF3',
#  'CF3NAME',
#  'DRUNK_DR',
#  'COUNTYNAME',
#  'CITYNAME',
#  'WEATHER1',
#  'WEATHER1NAME',
#  'WEATHER2',
#  'WEATHER2NAME',
#  'CF1',
#  'CF1NAME',
#  'CF2',
#  'CF2NAME',
#  'CF3',
#  'CF3NAME',
#  'DRUNK_DR',
#  'COUNTYNAME',
#  'CITYNAME',
#  'DRUNK_DR',
#  'COUNTYNAME',
#  'CITYNAME']

# %%
'year' in final.columns
# Out:
# False

# %%
final.to_csv('combined.csv')

# %%
final.head(10)
# Out:
#    STATE STATENAME  ST_CASE  VE_TOTAL  VE_FORMS  PVH_INVL  PEDS  PERSONS  \
# 0      1   Alabama    10001         1         1         0     0        1
# 1      1   Alabama    10002         1         1         0     0        1
# 2      1   Alabama    10003         1         1         0     0        2
# 3      1   Alabama    10004         1         1         0     0        1
# 4      1   Alabama    10005         2         2         0     0        2
# 5      1   Alabama    10006         1         1         0     0        2
# 6      1   Alabama    10007         1         1         0     0        2
# 7      1   Alabama    10008         1         1         0     1        1
# 8      1   Alabama    10009         1         1         0     0        1
# 9      1   Alabama    10010         2         2         0     0        2
#
#    PERMVIT  PERNOTMVIT  ...  NOT_MINNAME  ARR_HOUR     ARR_HOURNAME  ARR_MIN  \
# 0        1           0  ...      Unknown         2    2:00am-2:59am       58
# ...

# %%
len(final["ST_CASE"].unique())
# Out:
# 41133

# %%
sum1=0
for i in x:
    print(len(i["ST_CASE"].unique()))
    sum1+=len(i["ST_CASE"].unique())
print(sum)
# Out:
# 32538
# 34748
# 34560
# 33919
# 33487
# 35935
# 39785
# 244972

# %%
sum=0
for i in x:
    print(len(i))
    sum+=len(i)
print(sum)
# Out:
# 32538
# 34748
# 34560
# 33919
# 33487
# 35935
# 39785
# 244972

# %%
final = final.drop('ST_CASE', axis=1)

# %%
final.head(10)
# Out:
#    STATE STATENAME  VE_TOTAL  VE_FORMS  PVH_INVL  PEDS  PERSONS  PERMVIT  \
# 0      1   Alabama         1         1         0     0        1        1
# 1      1   Alabama         1         1         0     0        1        1
# 2      1   Alabama         1         1         0     0        2        2
# 3      1   Alabama         1         1         0     0        1        1
# 4      1   Alabama         2         2         0     0        2        2
# 5      1   Alabama         1         1         0     0        2        2
# 6      1   Alabama         1         1         0     0        2        2
# 7      1   Alabama         1         1         0     1        1        1
# 8      1   Alabama         1         1         0     0        1        1
# 9      1   Alabama         2         2         0     0        2        2
#
#    PERNOTMVIT  COUNTY  ...  NOT_MINNAME  ARR_HOUR     ARR_HOURNAME  ARR_MIN  \
# 0           0     127  ...      Unknown         2    2:00am-2:59am       58
# ...
